# %%
# %matplotlib inline
import pandas as pd, numpy as np, matplotlib.pyplot as plt
from sklearn import grid_search, linear_model as lm, cross_validation as cv, tree, preprocessing as prep

#iowa = pd.read_csv('IowaLiquor.csv',parse_dates=[0])
#iowa.columns = ['Date','StoreNo','City','Zip','CountyNo','County','CategoryNo','Category','VendorNo','ItemNo','Item','Volume','Cost','Retail','Quantity','TotSales','TotVolume','TotVolumeGals']
iowa
# Out:
#              Date  StoreNo             City    Zip  CountyNo         County  \
# 0      2015-11-04     3717           SUMNER  50674       9.0         Bremer
# 1      2016-03-02     2614        DAVENPORT  52807      82.0          Scott
# 2      2016-02-11     2106      CEDAR FALLS  50613       7.0     Black Hawk
# 3      2016-02-03     2501             AMES  50010      85.0          Story
# 4      2015-08-18     3654          BELMOND  50421      99.0         Wright
# 5      2015-04-20     2569     CEDAR RAPIDS  52402      57.0           Linn
# 6      2015-08-05     2596          OTTUMWA  52501      90.0        Wapello
# 7      2015-06-25     3456       CLEAR LAKE  50428      17.0    Cerro Gordo
# 8      2016-01-04     4757        BONDURANT  50035      77.0           Polk
# 9      2015-11-10     4346       SHELLSBURG  52332       6.0         Benton
# 10     2015-09-28     2648  WEST DES MOINES  50265      77.0           Polk
# 11     2015-10-28     2600        OSKALOOSA  52577      62.0        Mahaska
# 12     2015-01-22     3858        DAVENPORT  52806      82.0          Scott
# 13     2016-02-29     4673       WEST POINT  52656      56.0            Lee
# 14     2016-01-04     2670       CORALVILLE  52241      52.0        Johnson
# 15     2015-06-10     3717           SUMNER  50674       9.0         Bremer
# 16     2016-02-25     2130         WATERLOO  50703       7.0     Black Hawk
# 17     2015-12-29     2600        OSKALOOSA  52577      62.0        Mahaska
# 18     2015-12-26     4604           NEWTON  50208      50.0         Jasper
# 19     2015-03-04     2614        DAVENPORT  52807      82.0          Scott
# 20     2015-01-16     2590     CEDAR RAPIDS  52402      57.0           Linn
# 21     2015-01-13     3942           TOLEDO  52342      86.0           Tama
# 22     2015-03-24     3981     SIOUX CENTER  51250      84.0          Sioux
# 23     2015-11-12     4376       MASON CITY  50401      17.0    Cerro Gordo
# 24     2016-03-14     2618     CEDAR RAPIDS  52402      57.0           Linn
# 25     2015-02-03     3390          MILFORD  51351      30.0      Dickinson
# 26     2015-11-23     3565        IOWA CITY  52246      52.0        Johnson
# 27     2015-04-21     3963   COUNCIL BLUFFS  51501      78.0  Pottawattamie
# 28     2015-12-01     4375           GRIMES  50111      77.0           Polk
# 29     2015-01-14     2545        IOWA CITY  52245      52.0        Johnson
# ...           ...      ...              ...    ...       ...            ...
# 270925 2015-01-05     2837         WATERLOO  50702       7.0     Black Hawk
# 270926 2015-12-26     2478          ALTOONA  50009      77.0           Polk
# 270927 2015-08-31     2633       DES MOINES  50320      77.0           Polk
# 270928 2015-10-07     3896        IOWA CITY  52240      52.0        Johnson
# 270929 2016-01-25     5070           WILTON  52778      70.0      Muscatine
# 270930 2015-10-13     4634     CEDAR RAPIDS  52402      57.0           Linn
# 270931 2015-05-26     2602     WEBSTER CITY  50595      40.0       Hamilton
# 270932 2015-06-18     4604           NEWTON  50208      50.0         Jasper
# 270933 2015-02-26     4987             AMES  50010      85.0          Story
# 270934 2015-03-18     2623       SIOUX CITY  51104      97.0       Woodbury
# 270935 2015-06-08     5126       DES MOINES  50310      77.0           Polk
# 270936 2015-03-31     2552     CEDAR RAPIDS  52404      57.0           Linn
# 270937 2015-01-27     2553          CRESTON  50801      88.0          Union
# 270938 2015-04-29     3890     CEDAR RAPIDS  52405      57.0           Linn
# 270939 2015-05-04     4876         HIAWATHA  52233      57.0           Linn
# 270940 2015-01-21     2523      CENTERVILLE  52544       4.0      Appanoose
# 270941 2015-02-09     4856           LISBON  52253      57.0           Linn
# 270942 2015-06-15     2512        IOWA CITY  52240      52.0        Johnson
# 270943 2015-10-21     4438             AMES  50010      85.0          Story
# 270944 2016-03-22     2620  WINDSOR HEIGHTS  50311      77.0           Polk
# 270945 2015-06-11     2627       DES MOINES  50310      77.0           Polk
# 270946 2015-11-24     5162        URBANDALE  50322      77.0           Polk
# 270947 2015-05-12     4375           GRIMES  50111      77.0           Polk
# 270948 2015-04-08     2545        IOWA CITY  52245      52.0        Johnson
# 270949 2015-07-21     2529     CEDAR RAPIDS  52405      57.0           Linn
# 270950 2015-12-22     4057       DES MOINES  50316      77.0           Polk
# 270951 2015-11-04     5151        IDA GROVE  51445      47.0            Ida
# 270952 2015-10-20     5152         WATERLOO  50702       7.0     Black Hawk
# 270953 2015-11-20     3562  WEST BURLINGTON  52655      29.0     Des Moines
# 270954 2015-01-27     4446        URBANDALE  50322      77.0           Polk
#
#         CategoryNo                            Category  VendorNo  ItemNo  \
# 0        1051100.0                    APRICOT BRANDIES        55   54436
# 1        1011100.0                    BLENDED WHISKIES       395   27605
# 2        1011200.0           STRAIGHT BOURBON WHISKIES        65   19067
# 3        1071100.0                  AMERICAN COCKTAILS       395   59154
# 4        1031080.0                      VODKA 80 PROOF       297   35918
# 5        1041100.0                   AMERICAN DRY GINS       205   31473
# 6        1051010.0             AMERICAN GRAPE BRANDIES        85   52806
# 7        1012100.0                   CANADIAN WHISKIES        65   10628
# 8        1032080.0                      IMPORTED VODKA       370   34006
# 9        1081315.0                   CINNAMON SCHNAPPS        65   82610
# 10       1011250.0      SINGLE BARREL BOURBON WHISKIES        65   19235
# 11       1071100.0                  AMERICAN COCKTAILS        55   57148
# 12       1012100.0                   CANADIAN WHISKIES        65   15248
# 13       1081300.0                 PEPPERMINT SCHNAPPS       322   75211
# 14       1031200.0                      VODKA FLAVORED       380   41705
# 15       1051100.0                    APRICOT BRANDIES        55   54436
# 16       1031100.0                     100 PROOF VODKA       297   35913
# 17       1031200.0                      VODKA FLAVORED       380   41989
# 18       1081700.0         DISTILLED SPIRITS SPECIALTY       434   75087
# 19       1012100.0                   CANADIAN WHISKIES       434   13638
# 20       1031200.0                      VODKA FLAVORED       971   41474
# 21       1012100.0                   CANADIAN WHISKIES       115   11786
# 22       1011100.0                    BLENDED WHISKIES       260   25606
# 23       1022100.0                             TEQUILA       395   89196
# 24       1031080.0                      VODKA 80 PROOF       297   35926
# 25       1011300.0                  TENNESSEE WHISKIES        85   26827
# 26       1012100.0                   CANADIAN WHISKIES       260   11290
# 27       1011100.0                    BLENDED WHISKIES       434   24156
# 28       1031080.0                      VODKA 80 PROOF       380   37338
# 29       1081600.0                     WHISKEY LIQUEUR       260   66199
# ...            ...                                 ...       ...     ...
# 270925   1081200.0                      CREAM LIQUEURS       260   68306
# 270926   1022100.0                             TEQUILA       410   89646
# 270927   1031200.0                      VODKA FLAVORED       260   77699
# 270928   1031080.0                      VODKA 80 PROOF       300   36904
# 270929   1031080.0                      VODKA 80 PROOF       380   37346
# 270930   1031080.0                      VODKA 80 PROOF       297   35914
# 270931   1081900.0  MISC. AMERICAN CORDIALS & LIQUEURS        65   85526
# 270932   1011300.0                  TENNESSEE WHISKIES        85   26828
# 270933   1062310.0                          SPICED RUM       260   43336
# 270934   1051110.0                 BLACKBERRY BRANDIES        55   55068
# 270935   1011300.0                  TENNESSEE WHISKIES        85   86670
# 270936   1022100.0                             TEQUILA       395   89196
# 270937   1082900.0  MISC. IMPORTED CORDIALS & LIQUEURS        85   64676
# 270938   1031080.0                      VODKA 80 PROOF       260   37994
# 270939   1031200.0                      VODKA FLAVORED       380   42002
# 270940   1012200.0                     SCOTCH WHISKIES       305    4936
# 270941   1031080.0                      VODKA 80 PROOF        55   35948
# 270942   1011100.0                    BLENDED WHISKIES        65   24466
# 270943   1011200.0           STRAIGHT BOURBON WHISKIES        65   19061
# 270944   1081240.0               GREEN CREME DE MENTHE       434   79336
# 270945   1062200.0    PUERTO RICO & VIRGIN ISLANDS RUM        55   44215
# 270946   1031080.0                      VODKA 80 PROOF       301   38176
# 270947   1062310.0                          SPICED RUM       260   43334
# 270948   1062300.0                        FLAVORED RUM        35   43145
# 270949   1031100.0                     100 PROOF VODKA       300   36887
# 270950   1022100.0                             TEQUILA       410   88291
# 270951   1011200.0           STRAIGHT BOURBON WHISKIES       259   17956
# 270952   1011300.0                  TENNESSEE WHISKIES        85   26826
# 270953   1082900.0  MISC. IMPORTED CORDIALS & LIQUEURS       192   65258
# 270954   1031080.0                      VODKA 80 PROOF       260   37993
#
#           ...     Retail  Quantity  TotSales  TotVolume  TotVolumeGals  Year  \
# 0         ...       6.75        12     81.00       9.00           2.38  2015
# 1         ...      20.63         2     41.26       1.50           0.40  2016
# 2         ...      18.89        24    453.36      24.00           6.34  2016
# 3         ...      14.25         6     85.50      10.50           2.77  2016
# 4         ...      10.80        12    129.60      21.00           5.55  2015
# 5         ...      19.98         6    119.88      10.50           2.77  2015
# 6         ...       9.99         3     29.97       2.25           0.59  2015
# 7         ...      23.63         2     47.26       3.50           0.92  2015
# 8         ...      17.24         4     68.96       3.00           0.79  2016
# 9         ...      11.43         2     22.86       2.00           0.53  2015
# 10        ...      39.36         6    236.16       4.50           1.19  2015
# 11        ...       9.25         6     55.50      10.50           2.77  2015
# 12        ...      13.38         1     13.38       1.75           0.46  2015
# 13        ...      15.00        12    180.00       9.00           2.38  2016
# 14        ...      11.25        12    135.00      12.00           3.17  2016
# 15        ...       6.75         4     27.00       3.00           0.79  2015
# 16        ...       1.70        48     81.60       9.60           2.54  2016
# 17        ...       9.75        12    117.00       9.00           2.38  2015
# 18        ...       7.38        24    177.12      24.00           6.34  2015
# 19        ...      14.96         6     89.76      10.50           2.77  2015
# 20        ...      21.38         2     42.76       1.50           0.40  2015
# 21        ...       7.85        12     94.20       9.00           2.38  2015
# 22        ...      10.50        12    126.00       9.00           2.38  2015
# 23        ...      15.74        12    188.88       9.00           2.38  2015
# 24        ...       5.06        12     60.72       9.00           2.38  2016
# 25        ...      26.85        24    644.40      24.00           6.34  2015
# 26        ...      11.03         1     11.03       0.30           0.08  2015
# 27        ...       5.25         3     15.75       2.25           0.59  2015
# 28        ...      16.49         6     98.94      10.50           2.77  2015
# 29        ...       7.35         1      7.35       0.50           0.13  2015
# ...       ...        ...       ...       ...        ...            ...   ...
# 270925    ...       9.00         4     36.00       3.00           0.79  2015
# 270926    ...      46.50         6    279.00       4.50           1.19  2015
# 270927    ...      13.88        12    166.56      12.00           3.17  2015
# 270928    ...       2.70        48    129.60      18.00           4.76  2015
# 270929    ...       5.36         4     21.44       3.00           0.79  2016
# 270930    ...       2.90        12     34.80       4.50           1.19  2015
# 270931    ...       7.88        12     94.56       9.00           2.38  2015
# 270932    ...      44.51         2     89.02       3.50           0.92  2015
# 270933    ...      13.50         3     40.50       2.25           0.59  2015
# 270934    ...      15.00         2     30.00       3.50           0.92  2015
# 270935    ...      22.61         3     67.83       2.25           0.59  2015
# 270936    ...      15.74        12    188.88       9.00           2.38  2015
# 270937    ...      27.84         1     27.84       0.75           0.20  2015
# 270938    ...       7.13         3     21.39       1.12           0.30  2015
# 270939    ...       7.34         6     44.04       3.00           0.79  2015
# 270940    ...      18.05         4     72.20       3.00           0.79  2015
# 270941    ...      10.27         6     61.62      10.50           2.77  2015
# 270942    ...       8.27        12     99.24       9.00           2.38  2015
# 270943    ...      10.25         1     10.25       0.50           0.13  2015
# 270944    ...       7.13         2     14.26       1.50           0.40  2016
# 270945    ...       1.34        48     64.32       4.80           1.27  2015
# 270946    ...      14.48         4     57.92       3.00           0.79  2015
# 270947    ...       7.50         6     45.00       2.25           0.59  2015
# 270948    ...      12.75         3     38.25       2.25           0.59  2015
# 270949    ...       6.20         3     18.60       3.00           0.79  2015
# 270950    ...      30.45         4    121.80       1.20           0.32  2015
# 270951    ...      11.21         3     33.63       2.25           0.59  2015
# 270952    ...      22.61         6    135.66       4.50           1.19  2015
# 270953    ...      39.08         6    234.48      10.50           2.77  2015
# 270954    ...       4.13         8     33.04       1.60           0.42  2015
#
#         Quarter  Margin  PricePerLitre  TotMargin
# 0             4    2.25           6.75      27.00
# 1             1    6.88          20.63      13.76
# 2             1    6.30          18.89     151.20
# 3             1    4.75          14.25      28.50
# 4             3    3.60          10.80      43.20
# 5             2    6.66          19.98      39.96
# 6             3    3.33           9.99       9.99
# 7             2    7.88          23.63      15.76
# 8             1    5.75          17.24      23.00
# 9             4    3.81          11.43       7.62
# 10            3   13.12          39.36      78.72
# 11            4    3.25           9.25      19.50
# 12            1    4.46          13.38       4.46
# 13            1    5.00          15.00      60.00
# 14            1    3.75          11.25      45.00
# 15            2    2.25           6.75       9.00
# 16            1    0.57           1.70      27.36
# 17            4    3.25           9.75      39.00
# 18            4    2.46           7.38      59.04
# 19            1    4.99          14.96      29.94
# 20            1    7.13          21.38      14.26
# 21            1    2.62           7.85      31.44
# 22            1    3.50          10.50      42.00
# 23            4    5.25          15.74      63.00
# 24            1    1.69           5.06      20.28
# 25            1    8.95          26.85     214.80
# 26            4    3.68          11.03       3.68
# 27            2    1.75           5.25       5.25
# 28            4    5.50          16.49      33.00
# 29            1    2.45           7.35       2.45
# ...         ...     ...            ...        ...
# 270925        1    3.00           9.00      12.00
# 270926        4   15.50          46.50      93.00
# 270927        3    4.63          13.88      55.56
# 270928        4    0.90           2.70      43.20
# 270929        1    1.79           5.36       7.16
# 270930        4    0.97           2.90      11.64
# 270931        2    2.63           7.88      31.56
# 270932        2   14.84          44.51      29.68
# 270933        1    4.50          13.50      13.50
# 270934        1    5.00          15.00      10.00
# 270935        2    7.54          22.61      22.62
# 270936        1    5.25          15.74      63.00
# 270937        1    9.28          27.84       9.28
# 270938        2    2.38           7.13       7.14
# 270939        2    2.45           7.34      14.70
# 270940        1    6.02          18.05      24.08
# 270941        1    3.59          10.27      21.54
# 270942        2    2.76           8.27      33.12
# 270943        4    3.42          10.25       3.42
# 270944        1    2.38           7.13       4.76
# 270945        2    0.45           1.34      21.60
# 270946        4    4.83          14.48      19.32
# 270947        2    2.50           7.50      15.00
# 270948        2    4.25          12.75      12.75
# 270949        3    2.07           6.20       6.21
# 270950        4   10.15          30.45      40.60
# 270951        4    3.74          11.21      11.22
# 270952        4    7.54          22.61      45.24
# 270953        4   13.03          39.08      78.18
# 270954        1    1.38           4.13      11.04
#
# [270955 rows x 23 columns]

# %%
#Change dollar columns to a number
iowa['TotSales'] = iowa[['TotSales']].replace('[\$,]','',regex=True).astype(float)
iowa['Retail'] = iowa[['Retail']].replace('[\$,]','',regex=True).astype(float)
iowa['Cost'] = iowa[['Cost']].replace('[\$,]','',regex=True).astype(float)

# %%
import datetime as dt
#Add the Year variable
iowa['Year'] = pd.DatetimeIndex(iowa['Date']).year
#Quarter
iowa['Quarter'] = pd.DatetimeIndex(iowa['Date']).quarter
#TotalMargin
iowa['TotMargin'] = (iowa['Retail']-iowa['Cost'])*iowa['Quantity']
#PricePerLitre
iowa['PricePerLitre'] = iowa['TotSales']/iowa['Quantity']

# %%
daterange = lambda x:np.min(x)-np.max(x)



sales_2015q1 = pd.pivot_table(iowa[(iowa['Year']==2015) & (iowa['Quarter']==1)],
               index=['Quarter','StoreNo'],
               values=['TotSales',
                       'Date',
                       'Quantity',
                       'TotMargin',
                       'Bottles',
                       'TotVolume'
                      ],
               aggfunc = {'TotSales':{'TotSales':np.sum},
                          'TotMargin':{'TotMargin':np.sum},
                          'TotVolume':{'TotVolume':np.sum},
                          'Quantity':{'TotQty':np.sum},
                          'Date':{'DateRange':daterange},
                          'Quantity':{'TotNoSales':len}
                          
                         })


sales_2016q1 = pd.pivot_table(iowa[(iowa['Year']==2016) & (iowa['Quarter']==1)],
               index=['Quarter','StoreNo'],
               values=['TotSales'],
               aggfunc = sum)

sales_year = pd.pivot_table(iowa,
               index=['Year','StoreNo'],
               values=['TotSales'],
               aggfunc = sum)
sales_2015q1
# Out:
#                      Date TotMargin   Quantity TotVolume  TotSales
#                 DateRange TotMargin TotNoSales TotVolume  TotSales
# Quarter StoreNo
# 1       2106     -77 days  13108.37        129   2526.10  39287.29
#         2113     -77 days    944.72         42    177.11   2833.25
#         2130     -77 days   8108.68         87   1447.25  24272.57
#         2152     -77 days    668.60         32    151.74   2003.46
#         2178     -77 days   1961.28         48    409.81   5856.41
#         2190     -84 days   9828.30        347   1666.58  29452.92
#         2191     -84 days   9723.40        151   1957.28  29085.57
#         2200     -77 days   1641.80         84    367.72   4900.43
#         2205     -84 days   2138.97         70    375.38   6407.74
#         2228     -84 days   1736.43         60    405.62   5193.97
#         2233     -84 days   1796.01         43    419.85   5374.55
#         2238     -70 days    286.28          7     42.00    858.61
#         2248     -77 days   4227.24        101    649.54  12663.68
#         2285     -77 days   3345.90         58    503.45  10019.12
#         2290     -77 days   4083.72        160    817.58  12191.26
#         2327     -84 days    751.31         43    183.27   2253.60
#         2353     -84 days   5946.70         99   1645.40  17382.60
#         2367     -84 days    674.80         22    158.00   2023.44
#         2413     -83 days   7501.02        113   1538.37  22459.16
#         2445     -84 days    405.69         32     95.11   1215.08
#         2448     -84 days   1887.26        112    365.02   5655.92
#         2459     -77 days    538.07         22    137.00   1609.57
#         2460     -84 days   2256.58         82    575.26   6746.61
#         2465     -83 days   1875.51         98    400.12   5615.99
#         2475     -84 days   1891.99         20    654.15   5672.76
#         2478     -84 days   1486.90         19    210.00   4459.85
#         2487     -84 days   2427.71        120    510.89   7256.60
#         2498     -84 days     93.13         10     27.87    279.22
#         2500     -77 days  13435.42        282   3160.76  40234.90
#         2501     -77 days  10502.76        321   2168.65  31412.95
# ...                   ...       ...        ...       ...       ...
#         5086     -42 days    270.50          8     59.70    810.60
#         5088     -70 days    159.78          4     30.75    479.16
#         5089     -77 days    294.74         33     55.10    884.03
#         5090     -73 days    735.53         20    132.59   2193.89
#         5091     -10 days    178.72         11     36.88    523.82
#         5092     -63 days    605.58         13     99.00   1815.54
#         5093     -63 days    811.13         56    161.92   2430.57
#         5094     -56 days    172.14          6     34.72    511.86
#         5096     -28 days    683.46         24    140.50   2040.42
#         5097     -56 days   1056.36         25    210.00   3160.02
#         5098     -46 days    453.97         22     68.45   1360.74
#         5099     -40 days    417.05         16     70.31   1250.49
#         5100     -42 days    727.56         14    111.90   2180.76
#         5101     -42 days    567.27         12     69.95   1701.47
#         5102     -53 days   9237.52        133   1451.75  27695.76
#         5103       0 days     14.26          1      1.50     42.76
#         5104       0 days    520.89         49     97.78   1555.83
#         5105     -21 days    911.14         34    211.32   2708.56
#         5106     -21 days    907.68         14    219.00   2691.84
#         5108     -28 days    333.38         14     63.75    999.95
#         5112     -28 days    268.02          4     46.50    803.56
#         5113     -21 days    809.76         16    116.40   2427.84
#         5114       0 days    135.39          6     21.37    406.02
#         5115       0 days    200.34          4     38.10    601.02
#         5116     -19 days    469.17         23    121.00   1406.57
#         5119       0 days     37.50          1      4.50    112.50
#         5128       0 days    159.08          3     24.00    477.00
#         9001     -28 days    780.48          5     58.50   2341.08
#         9002     -63 days   1622.34          9    135.00   4865.16
#         9010     -70 days   1287.84          8    135.00   3861.60
#
# [1262 rows x 5 columns]

# %%
sales_quarter['']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-4faedcf5ee90> in <module>()
# ----> 1 sales_quarterstore['1']
#
# /home/chong/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# /home/chong/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# /home/chong/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1348         res = cache.get(item)
#    1349         if res is None:
# -> 1350             values = self._data.get(item)
#    1351             res = self._box_item_values(item, values)
#    1352             cache[item] = res
#
# /home/chong/anaconda2/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3288
#    3289             if not isnull(item):
# -> 3290                 loc = self.items.get_loc(item)
#    3291             else:
#    3292                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /home/chong/anaconda2/lib/python2.7/site-packages/pandas/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
# -> 1947                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    1948
#    1949         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: '1'

# %%
sales_quarter1store = sales_quarterstore[sales_quarterstore.index.map(lambda x: x[0]==1)]

# %%
treeReg = tree.DecisionTreeRegressor()
linReg = lm.LinearRegression()
TSReg = lm.TheilSenRegressor()
RANReg = lm.RANSACRegressor()

# %%
np.min(iowa['Date'])
# Out:
# Timestamp('2015-01-05 00:00:00')

# %%
clf = grid_search.GridSearchCV(ols,{'max_depth':range(1,10)})

clf.fit(train_X,train_Y)
clf.best_estimator_.max_depth
